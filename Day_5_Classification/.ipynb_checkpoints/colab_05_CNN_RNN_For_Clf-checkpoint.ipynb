# %%
# %%writefile requirements.txt
# torch
# numpy==1.23
# pandas
# scikit-learn
# razdel
# gensim==3.8.3
# Out:
# Writing requirements.txt

# %%
# !pip install --upgrade -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (2.0.0+cu118)
# Collecting numpy==1.23
#   Downloading numpy-1.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (1.4.4)
# Collecting pandas
#   Downloading pandas-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (1.2.2)
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Collecting gensim==3.8.3
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 17.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3->-r requirements.txt (line 6)) (1.10.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim==3.8.3->-r requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (3.10.7)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch->-r requirements.txt (line 1)) (3.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch->-r requirements.txt (line 1)) (16.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 3)) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch->-r requirements.txt (line 1)) (1.3.0)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... done
#   Created wheel for gensim: filename=gensim-3.8.3-cp39-cp39-linux_x86_64.whl size=26528050 sha256=3d6b9ccd35c4e1dcb165d899f8d91ad9a27b744759f9f3493786507f3c60839c
#   Stored in directory: /root/.cache/pip/wheels/ca/5d/af/618594ec2f28608c1d6ee7d2b7e95a3e9b06551e3b80a491d6
# Successfully built gensim
# Installing collected packages: razdel, numpy, pandas, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.1
#     Uninstalling gensim-4.3.1:
#       Successfully uninstalled gensim-4.3.1
# Successfully installed gensim-3.8.3 numpy-1.23.0 pandas-2.0.0 razdel-0.5.0

# %%
# Restart kernel
import os
os._exit(0)

# %% [markdown]
# ## Датасет
#
# Новый день - новый датасет!
#
# http://study.mokoron.com/
#
# https://habr.com/ru/company/mailru/blog/417767/
#
# https://habr.com/ru/post/472988/

# %%
# !rm negative.csv
# !rm positive.csv
# !wget https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv
# !wget https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv
# Out:
# rm: cannot remove 'negative.csv': No such file or directory
# rm: cannot remove 'positive.csv': No such file or directory
# --2023-04-06 15:41:56--  https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/r6u59ljhhjdg6j0/negative.csv [following]
# --2023-04-06 15:41:56--  https://www.dropbox.com/s/raw/r6u59ljhhjdg6j0/negative.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com/cd/0/inline/B5qZs5LMgjzkrHeiafCMPRuVB5nGCRd5kXDa6_a0uw2M6exgssS7Obe9Ui3EIGGVe17NS9Vfwms3MgQA6RIUeOfVLVvhX2a_DHmfQhmbDX0chE3jOaJLlfpLvfsxnjYSvqUhnW7hvS04VxOZwViNh931M7u9JfKvCe46myMOnBKMcw/file# [following]
# --2023-04-06 15:41:57--  https://ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com/cd/0/inline/B5qZs5LMgjzkrHeiafCMPRuVB5nGCRd5kXDa6_a0uw2M6exgssS7Obe9Ui3EIGGVe17NS9Vfwms3MgQA6RIUeOfVLVvhX2a_DHmfQhmbDX0chE3jOaJLlfpLvfsxnjYSvqUhnW7hvS04VxOZwViNh931M7u9JfKvCe46myMOnBKMcw/file
# Resolving ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com (ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com (ucd14d14cb93cf29102554e54cc8.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24450101 (23M) [text/plain]
# Saving to: ‘negative.csv’
#
# negative.csv        100%[===================>]  23.32M  54.9MB/s    in 0.4s
#
# 2023-04-06 15:41:58 (54.9 MB/s) - ‘negative.csv’ saved [24450101/24450101]
#
# --2023-04-06 15:41:58--  https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6016:18::a27d:112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/fnpq3z4bcnoktiv/positive.csv [following]
# --2023-04-06 15:41:58--  https://www.dropbox.com/s/raw/fnpq3z4bcnoktiv/positive.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com/cd/0/inline/B5pYFrhbcLCMdqs2PXPXCaCbuuW0EH6D7HzCSroFT9yULTEJDAd47qxigmQ3kCU9kLtC2ixerk1VmfyRt8-CFOZV78Dw-ABQnewLsMzF4M7GKwdpY00jdcDwrGR5NDamW9gygoIaZSxSEkoNjHY_10JCMalQ-xFU4lPGIey8LHQikw/file# [following]
# --2023-04-06 15:41:58--  https://ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com/cd/0/inline/B5pYFrhbcLCMdqs2PXPXCaCbuuW0EH6D7HzCSroFT9yULTEJDAd47qxigmQ3kCU9kLtC2ixerk1VmfyRt8-CFOZV78Dw-ABQnewLsMzF4M7GKwdpY00jdcDwrGR5NDamW9gygoIaZSxSEkoNjHY_10JCMalQ-xFU4lPGIey8LHQikw/file
# Resolving ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com (ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com (ucbabc51e11cd2b1ae4ec6cd72ac.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26233379 (25M) [text/plain]
# Saving to: ‘positive.csv’
#
# positive.csv        100%[===================>]  25.02M  70.5MB/s    in 0.4s
#
# 2023-04-06 15:41:59 (70.5 MB/s) - ‘positive.csv’ saved [26233379/26233379]

# %%
import re
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

n = ['id', 'date', 'name', 'text', 'typr', 'rep', 'rtw', 'faw', 'stcount', 'foll', 'frien', 'listcount']
data_positive = pd.read_csv('positive.csv', sep=';', on_bad_lines='skip', names=n, usecols=['text'])
data_negative = pd.read_csv('negative.csv', sep=';', on_bad_lines='skip', names=n, usecols=['text'])

sample_size = min(data_positive.shape[0], data_negative.shape[0])
raw_data = np.concatenate((data_positive['text'].values[:sample_size], data_negative['text'].values[:sample_size]), axis=0)

def preprocess_text(text):
    text = text.lower().replace("ё", "е")
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', text)
    text = re.sub('@[^\s]+', 'USER', text)
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +', ' ', text)
    return text.strip()

df_train = pd.DataFrame(columns=['text', 'label'])
df_val = pd.DataFrame(columns=['text', 'label'])
df_test = pd.DataFrame(columns=['text', 'label'])

data = [preprocess_text(t) for t in raw_data]
labels = [1] * sample_size + [0] * sample_size
df_train['text'], df_test['text'], df_train['label'], df_test['label'] = train_test_split(data, labels, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_train, test_size=0.2, random_state=1)
df_train
# Out:
#                                                      text  label
# 85913   раньше все встречались у фонтана в гуме а тепе...      1
# 42792   ни когда не пойму любовь женщины к женщине хот...      1
# 85556   два сеанса в кино вот что я люблю парам пам па...      1
# 36360   я нашел мой наряд для кэти перри USER URL via ...      1
# 154940          USER ууууу всеее развод обидки и все дела      1
# ...                                                   ...    ...
# 73349   закидываю свой вконтакторостер строчками из пе...      1
# 109259  гребаный понедельник гребанные 4 пары хочу дом...      0
# 50057   болячки вроде подживают но губы увеличелись в ...      0
# 5192        USER я знала что она добрая а за что она тебе      1
# 128037  USER вместо похода в кино пришлось тащиться в ...      0
#
# [143260 rows x 2 columns]

# %%
from collections import Counter
from razdel import tokenize

class Vocabulary:
    def __init__(self):
        self.word2index = {
            "<pad>": 0,
            "<unk>": 1
        }
        self.index2word = ["<pad>", "<unk>"]

    def build(self, texts, min_count=7):
        words_counter = Counter(token for tokens in texts for token in tokens)
        for word, count in words_counter.most_common():
            if count >= min_count:
                self.word2index[word] = len(self.word2index)
        self.index2word = [word for word, _ in sorted(self.word2index.items(), key=lambda x: x[1])]
    
    @property
    def size(self):
        return len(self.index2word)
    
    def top(self, n=100):
        return self.index2word[1:n+1]
    
    def get_index(self, word):
        return self.word2index.get(word, 0)
    
    def get_word(self, index):
        return self.index2word[index]

vocabulary = Vocabulary()
train_texts = df_train["text"].tolist()
train_texts = [[token.text for token in tokenize(text)] for text in train_texts]
vocabulary.build(train_texts)
assert vocabulary.word2index[vocabulary.index2word[10]] == 10
print(vocabulary.size)
print(vocabulary.top(100))
# Out:
# 17198
# ['<unk>', 'USER', 'не', 'я', 'и', 'в', 'на', 'rt', 'а', 'что', 'URL', 'с', 'как', 'у', 'все', 'меня', 'то', 'это', 'так', 'мне', 'd', 'но', 'ты', 'ну', 'по', 'за', 'еще', 'уже', 'вот', 'да', 'же', 'только', 'сегодня', 'о', 'бы', 'нет', 'когда', 'хочу', 'к', 'очень', 'тебя', 'из', 'он', '3', 'день', 'просто', 'мы', 'будет', '2', 'от', 'было', 'если', 'тебе', 'теперь', 'надо', 'даже', 'тоже', 'завтра', 'кто', 'до', 'там', 'его', '1', 'вообще', 'есть', 'для', 'она', 'сейчас', 'спасибо', 'нас', 'буду', 'почему', 'блин', 'могу', 'люблю', 'без', 'знаю', 'вы', 'они', 'тут', 'или', 'раз', 'мой', 'чем', 'ничего', 'со', 'больше', 'всегда', '5', 'хорошо', 'дома', 'про', 'всем', 'можно', 'ее', 'может', 'год', 'потом', 'был', 'спать']

# %%
train_labels = df_train["label"].tolist()
val_labels = df_val["label"].tolist()
test_labels = df_test["label"].tolist()
train_texts = [[token.text for token in tokenize(text)] for text in df_train["text"].tolist()]
val_texts = [[token.text for token in tokenize(text)] for text in df_val["text"].tolist()]
test_texts = [[token.text for token in tokenize(text)] for text in df_test["text"].tolist()]

# %%
import torch
np.random.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time

def get_next_batch(texts, labels, max_seq_len=100, batch_size=128):
    indices = np.arange(len(texts))
    np.random.shuffle(indices)
    batch_begin = 0
    while batch_begin < len(texts):
        batch_indices = indices[batch_begin: batch_begin + batch_size]
        batch = []
        batch_labels = []
        batch_max_len = 0
        for data_ind in batch_indices:
            batch_labels.append(labels[data_ind])
            sample = [vocabulary.get_index(token) for token in texts[data_ind]][:max_seq_len]
            batch_max_len = max(batch_max_len, len(sample))
            sample += [0] * (max_seq_len - len(sample))
            batch.append(sample)
        batch_begin += batch_size
        batch = torch.cuda.LongTensor(batch)[:, :batch_max_len]
        yield batch, torch.cuda.LongTensor(batch_labels)


def train_model(model, texts, labels, val_texts, val_labels, epochs_count=10, 
                loss_every_nsteps=1000, lr=0.01, save_path="model.pt", device_name="cuda"):
    params_count = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("Trainable params: {}".format(params_count))
    device = torch.device(device_name)
    model = model.to(device)
    total_loss = 0
    start_time = time.time()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_function = nn.CrossEntropyLoss().cuda()
    prev_avg_val_loss = None
    for epoch in range(epochs_count):
        model.train()
        for step, (batch, batch_labels) in enumerate(get_next_batch(texts, labels)):
            logits = model(batch) # Прямой проход
            loss = loss_function(logits, batch_labels) # Подсчёт ошибки
            loss.backward() # Подсчёт градиентов dL/dw
            optimizer.step() # Градиентный спуск или его модификации (в данном случае Adam)
            optimizer.zero_grad() # Зануление градиентов, чтобы их спокойно менять на следующей итерации
            total_loss += loss.item()
        val_total_loss = 0
        val_batch_count = 0
        model.eval()
        for _, (batch, batch_labels) in enumerate(get_next_batch(val_texts, val_labels)):
            logits = model(batch) # Прямой проход
            val_total_loss += loss_function(logits, batch_labels) # Подсчёт ошибки
            val_batch_count += 1
        avg_val_loss = val_total_loss/val_batch_count
        print("Epoch = {}, Avg Train Loss = {:.4f}, Avg val loss = {:.4f}, Time = {:.2f}s".format(epoch, total_loss / loss_every_nsteps, avg_val_loss, time.time() - start_time))
        total_loss = 0
        start_time = time.time()

        if prev_avg_val_loss is not None and avg_val_loss > prev_avg_val_loss:
            model.load_state_dict(torch.load(save_path))
            model.eval()
            break
        prev_avg_val_loss = avg_val_loss
        torch.save(model.state_dict(), save_path)

# %%
from sklearn.metrics import accuracy_score

def test_model(model, texts, labels):
    predicted_labels = []
    true_labels = []
    model.eval()
    for step, (batch, batch_labels) in enumerate(get_next_batch(texts, labels)):
        logits = model(batch) # Прямой проход
        predicted_labels.extend(torch.max(logits.detach().cpu(), 1)[1].numpy())
        true_labels.extend(batch_labels.detach().cpu().numpy())
    print(accuracy_score(true_labels, predicted_labels))

# %% [markdown]
# ## Сеть прямого распространения

# %%
class FFModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=64, hidden_dim=48):
        super().__init__()
        
        self.embeddings_layer = nn.Embedding(vocab_size, embedding_dim)
        self.hidden_layer = nn.Linear(embedding_dim, hidden_dim)
        self.relu_layer = nn.ReLU()
        self.dropout_layer = nn.Dropout(0.2)
        self.out_layer = nn.Linear(hidden_dim, 2)

    def forward(self, inputs):
        projections = self.embeddings_layer.forward(inputs)
        projections = self.dropout_layer(self.relu_layer(self.hidden_layer(projections)))
        pooling = torch.max(projections, 1)[0]
        output = self.out_layer.forward(pooling)
        return output

model = FFModel(vocabulary.size, 64)
train_model(model, train_texts, train_labels, val_texts, val_labels)
test_model(model, test_texts, test_labels)
# Out:
# Trainable params: 1103890
# Epoch = 0, Avg Train Loss = 0.5968, Avg val loss = 0.4853, Time = 5.74s
# Epoch = 1, Avg Train Loss = 0.5278, Avg val loss = 0.4860, Time = 4.78s
# 0.7511949966495421

# %% [markdown]
# ## Свёрточная сеть
# ![Conv example](https://image.ibb.co/e6t8ZK/Convolution.gif)
#
# *From [Feature extraction using convolution](http://deeplearning.stanford.edu/wiki/index.php/Feature_extraction_using_convolution).*
# ![NLP conv example](https://user-images.githubusercontent.com/6512394/41590312-b1c28fca-73f1-11e8-9123-e26a03853cc7.png)
#
# *From [(Text-Classification-Pytorch)](https://github.com/dongjun-Lee/text-classification-models-tf)*

# %%
class CnnModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=32, filters=((2, 10), (3, 8))):
        super().__init__()
        
        self.embeddings_layer = nn.Embedding(vocab_size, embedding_dim)
        self.filters = []
        all_filters_count = 0
        for kernel_size, filters_count in filters:
            all_filters_count += filters_count
            self.filters.append(nn.Conv2d(1, filters_count, (kernel_size, embedding_dim), padding=(1, 0)))
        self.filters = nn.ModuleList(self.filters)
        self.relu_layer = nn.ReLU()
        self.dropout_layer = nn.Dropout(0.2)
        self.out_layer = nn.Linear(all_filters_count, 2)

    def forward(self, inputs):
        projections = self.embeddings_layer.forward(inputs)
        projections = projections.unsqueeze(1)
        results = []
        for f in self.filters:
            convolved = self.dropout_layer(self.relu_layer(f(projections))).squeeze(3)
            pooling = torch.max(convolved, 2)[0]
            results.append(pooling)
        output = torch.cat(results, 1)
        output = self.out_layer.forward(output)
        return output

model = CnnModel(vocabulary.size, 64)
train_model(model, train_texts, train_labels, val_texts, val_labels)
test_model(model, test_texts, test_labels)
# Out:
# Trainable params: 1103544
# Epoch = 0, Avg Train Loss = 0.5916, Avg val loss = 0.4814, Time = 17.61s
# Epoch = 1, Avg Train Loss = 0.5022, Avg val loss = 0.4710, Time = 9.97s
# Epoch = 2, Avg Train Loss = 0.4542, Avg val loss = 0.4801, Time = 9.94s
# 0.7642617824436007

# %% [markdown]
# ## Рекуррентные сети
#
# ![rnn](http://colah.github.io/posts/2015-08-Understanding-LSTMs/img/LSTM3-chain.png)
# *From [(Understanding LSTM Networks)](http://colah.github.io/posts/2015-08-Understanding-LSTMs)*

# %%
class RnnModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=32, filters=((2, 10), (3, 8))):
        super().__init__()
        
        self.embeddings_layer = nn.Embedding(vocab_size, embedding_dim)
        self.lstm_layer = nn.LSTM(embedding_dim, embedding_dim, batch_first=True)
        self.dropout_layer = nn.Dropout(0.2)
        self.out_layer = nn.Linear(embedding_dim, 2)

    def forward(self, inputs):
        print('inputs'.ljust(30), inputs.size())
        projections = self.embeddings_layer.forward(inputs)
        print('projections'.ljust(30), projections.size())
        output, (final_hidden_state, final_cell_state) = self.lstm_layer(projections)
        print('final_hidden_state'.ljust(30), final_hidden_state[-1].size())
        hidden = self.dropout_layer(final_hidden_state[-1])
        print('hidden'.ljust(30), hidden.size())
        output = self.out_layer.forward(hidden)
        print('logoutputits'.ljust(30), output.size())
        print()
        return output

model = RnnModel(vocabulary.size, 64)
train_model(model, train_texts, train_labels, val_texts, val_labels)
test_model(model, test_texts, test_labels)
# Out:
# Trainable params: 1134082
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 23])
# projections                    torch.Size([128, 23, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 43])
# projections                    torch.Size([128, 43, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 40])
# projections                    torch.Size([128, 40, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 48])
# projections                    torch.Size([128, 48, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 30])
# projections                    torch.Size([128, 30, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 31])
# projections                    torch.Size([128, 31, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 22])
# projections                    torch.Size([128, 22, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 23])
# projections                    torch.Size([128, 23, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 32])
# projections                    torch.Size([128, 32, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 31])
# projections                    torch.Size([128, 31, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 30])
# projections                    torch.Size([128, 30, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 23])
# projections                    torch.Size([128, 23, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 24])
# projections                    torch.Size([128, 24, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 55])
# projections                    torch.Size([128, 55, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 23])
# projections                    torch.Size([128, 23, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 25])
# projections                    torch.Size([128, 25, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 26])
# projections                    torch.Size([128, 26, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 29])
# projections                    torch.Size([128, 29, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 22])
# projections                    torch.Size([128, 22, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 28])
# projections                    torch.Size([128, 28, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
#
# inputs                         torch.Size([128, 27])
# projections                    torch.Size([128, 27, 64])
# final_hidden_state             torch.Size([128, 64])
# hidden                         torch.Size([128, 64])
# logoutputits                   torch.Size([128, 2])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-34aad4b23497> in <cell line: 24>()
#      22
#      23 model = RnnModel(vocabulary.size, 64)
# ---> 24 train_model(model, train_texts, train_labels, val_texts, val_labels)
#      25 test_model(model, test_texts, test_labels)
#
# <ipython-input-56-b44de30638ec> in train_model(model, texts, labels, val_texts, val_labels, epochs_count, loss_every_nsteps, lr, save_path, device_name)
#      41             loss = loss_function(logits, batch_labels) # Подсчёт ошибки
#      42             loss.backward() # Подсчёт градиентов dL/dw
# ---> 43             optimizer.step() # Градиентный спуск или его модификации (в данном случае Adam)
#      44             optimizer.zero_grad() # Зануление градиентов, чтобы их спокойно менять на следующей итерации
#      45             total_loss += loss.item()
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     278                                                f"but got {result}.")
#     279
# --> 280                 out = func(*args, **kwargs)
#     281                 self._optimizer_step_code()
#     282
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      31         try:
#      32             torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33             ret = func(self, *args, **kwargs)
#      34         finally:
#      35             torch.set_grad_enabled(prev_grad)
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/adam.py in step(self, closure)
#     139                 state_steps)
#     140
# --> 141             adam(
#     142                 params_with_grad,
#     143                 grads,
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     279         func = _single_tensor_adam
#     280
# --> 281     func(params,
#     282          grads,
#     283          exp_avgs,
#
# /usr/local/lib/python3.9/dist-packages/torch/optim/adam.py in _multi_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     423     assert not differentiable, "_foreach ops don't support autograd"
#     424
# --> 425     grouped_tensors = _group_tensors_by_device_and_dtype([params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps])
#     426     for (device_params, device_grads, device_exp_avgs, device_exp_avg_sqs,
#     427          device_max_exp_avg_sqs, device_state_steps) in grouped_tensors.values():
#
# /usr/local/lib/python3.9/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# KeyboardInterrupt:

# %% [markdown]
# ### Задание 1
# Сделайте то же самое, но с bidirectional LSTM

# %%
class BidirRnnModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=32, filters=((2, 10), (3, 8))):
        super().__init__()
        
        self.embeddings_layer = nn.Embedding(vocab_size, embedding_dim)
        self.lstm_layer = nn.LSTM(embedding_dim, embedding_dim, batch_first=True, bidirectional=True)
        self.dropout_layer = nn.Dropout(0.2)
        self.out_layer = nn.Linear(embedding_dim*2, 2)

    def forward(self, inputs):
        projections = self.embeddings_layer(inputs)
        output, (final_hidden_state, final_cell_state) = self.lstm_layer(projections)
        hid_cat = torch.cat((final_hidden_state[-2], final_hidden_state[-1]), dim=1)
        hidden = self.dropout_layer(hid_cat)
        output = self.out_layer(hidden)
        return output

model = BidirRnnModel(vocabulary.size, 64)
train_model(model, train_texts, train_labels, val_texts, val_labels)
test_model(model, test_texts, test_labels)
# Out:
# Trainable params: 1167490
# Epoch = 0, Avg Train Loss = 0.5817, Avg val loss = 0.4736, Time = 6.15s
# Epoch = 1, Avg Train Loss = 0.4835, Avg val loss = 0.4697, Time = 6.59s
# Epoch = 2, Avg Train Loss = 0.4402, Avg val loss = 0.4812, Time = 5.61s
# 0.7672325217779763

# %% [markdown]
# ### Задание 2
# Сделайте то же самое, но с char-level CNN

# %%
train_texts = [list(text) for text in df_train["text"].tolist()]
val_texts   = [list(text) for text in df_val["text"].tolist()]
test_texts  = [list(text) for text in df_test["text"].tolist()]

vocabulary = Vocabulary()
vocabulary.build(train_texts)

# %%
model = CnnModel(vocabulary.size, 64)
train_model(model, train_texts, train_labels, val_texts, val_labels)
test_model(model, test_texts, test_labels)
# Out:
# Trainable params: 7672
# Epoch = 0, Avg Train Loss = 0.6752, Avg val loss = 0.5878, Time = 20.51s
# Epoch = 1, Avg Train Loss = 0.6565, Avg val loss = 0.5724, Time = 19.28s
# Epoch = 2, Avg Train Loss = 0.6518, Avg val loss = 0.5685, Time = 20.66s
# Epoch = 3, Avg Train Loss = 0.6507, Avg val loss = 0.5756, Time = 19.90s
# 0.6878490060308242

# %% [markdown]
# ### Задание 3
# Сделайте то же самое, но с предобученными пословными эмбеддингами

# %%
# https://rusvectores.org/ru/models/
# !wget http://vectors.nlpl.eu/repository/20/187.zip
# !unzip 187.zip -d rusvetores_187

from gensim.models import KeyedVectors
fasttext_model = KeyedVectors.load("rusvetores_187/model.model")

# %%
def get_text_embedding(model, phrase):
    embeddings = np.array([model.get_vector(word.text.lower()) if word.text.lower() in model.vocab else np.zeros((model.vector_size,))
                           for word in tokenize(phrase)])
    return np.mean(embeddings, axis=0)

X_train = np.zeros((len(df_train["text"]), fasttext_model.vector_size))
for i, embedding in enumerate(df_train["text"]):
    X_train[i, :] = get_text_embedding(fasttext_model, embedding)

X_val = np.zeros((len(df_val["text"]), fasttext_model.vector_size))
for i, embedding in enumerate(df_val["text"]):
    X_train[i, :] = get_text_embedding(fasttext_model, embedding)

X_test = np.zeros((len(df_test["text"]), fasttext_model.vector_size))
for i, embedding in enumerate(df_test["text"]):
    X_train[i, :] = get_text_embedding(fasttext_model, embedding)

X_train = X_train.tolist()
X_val = X_val.tolist()
X_test = X_test.tolist()

# %%
class RnnModel_2(nn.Module):
    def __init__(self, vocab_size, embedding_dim=32):
        super().__init__()
        
        self.lstm_layer = nn.LSTM(vocab_size, embedding_dim, batch_first=True)
        self.dropout_layer = nn.Dropout(0.2)
        self.out_layer = nn.Linear(embedding_dim, 2)

    def forward(self, inputs):
        output, (final_hidden_state, final_cell_state) = self.lstm_layer(inputs)
        hidden = self.dropout_layer(output)
        output = self.out_layer.forward(hidden)
        return output

# %%
def get_next_batch(texts, labels, batch_size=128):
    indices = np.arange(len(texts))
    np.random.shuffle(indices)
    batch_begin = 0
    while batch_begin < len(texts):
        batch_indices = indices[batch_begin: batch_begin + batch_size]
        batch, batch_labels = [], []
        for data_ind in batch_indices:
            text_ind = texts[data_ind]
            batch.append(text_ind)
            batch_labels.append(labels[data_ind])
        batch_begin += batch_size
    yield torch.cuda.FloatTensor(batch), torch.cuda.LongTensor(batch_labels)

def train_model(model, texts, labels, val_texts, val_labels, epochs_count=10, 
                loss_every_nsteps=1000, lr=0.01, save_path="model.pt", device_name="cuda"):
    params_count = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("Trainable params: {}".format(params_count))
    device = torch.device(device_name)
    model = model.to(device)
    total_loss = 0
    start_time = time.time()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_function = nn.CrossEntropyLoss().cuda()
    prev_avg_val_loss = None
    
    for epoch in range(epochs_count):
        model.train()
        for step, (batch, batch_labels) in enumerate(get_next_batch(texts, labels)):
            logits = model(batch) # Прямой проход
            loss = loss_function(logits, batch_labels) # Подсчёт ошибки
            loss.backward() # Подсчёт градиентов dL/dw
            optimizer.step() # Градиентный спуск или его модификации (в данном случае Adam)
            optimizer.zero_grad() # Зануление градиентов, чтобы их спокойно менять на следующей итерации
            total_loss += loss.item()
        val_total_loss = 0
        val_batch_count = 0
        model.eval()

        for _, (batch, batch_labels) in enumerate(get_next_batch(val_texts, val_labels)):
            logits = model(batch) # Прямой проход
            val_total_loss += loss_function(logits, batch_labels) # Подсчёт ошибки
            val_batch_count += 1
        avg_val_loss = val_total_loss/val_batch_count
        print("Epoch = {}, Avg Train Loss = {:.4f}, Avg val loss = {:.4f}, Time = {:.2f}s".format(epoch, total_loss / loss_every_nsteps, avg_val_loss, time.time() - start_time))
        total_loss = 0
        start_time = time.time()

        if prev_avg_val_loss is not None and avg_val_loss > prev_avg_val_loss:
            model.load_state_dict(torch.load(save_path))
            model.eval()
            break
        prev_avg_val_loss = avg_val_loss
        torch.save(model.state_dict(), save_path)

def test_model(model, texts, labels):
    predicted_labels = []
    true_labels = []
    model.eval()
    for step, (batch, batch_labels) in enumerate(get_next_batch(texts, labels)):
        logits = model(batch) # Прямой проход
        predicted_labels.extend(torch.max(logits.detach().cpu(), 1)[1].numpy())
        true_labels.extend(batch_labels.detach().cpu().numpy())
    print(accuracy_score(true_labels, predicted_labels))

# %%
model = RnnModel_2(fasttext_model.vector_size, 64)
train_model(model, X_train, train_labels, X_val, val_labels)
test_model(model, X_test, test_labels)
# Out:
# Trainable params: 93826
# Epoch = 0, Avg Train Loss = 0.0007, Avg val loss = 0.7002, Time = 0.08s
# Epoch = 1, Avg Train Loss = 0.0007, Avg val loss = 0.6956, Time = 0.07s
# Epoch = 2, Avg Train Loss = 0.0007, Avg val loss = 0.6946, Time = 0.07s
# Epoch = 3, Avg Train Loss = 0.0008, Avg val loss = 0.6873, Time = 0.07s
# Epoch = 4, Avg Train Loss = 0.0007, Avg val loss = 0.6979, Time = 0.07s
# 0.5612244897959183

# %% [markdown]
# ### Задание 4*
# Сделайте то же самое, но с точностью >80%

# %% [markdown]
# # Генерация имён: код с семинара

# %%
# !wget https://download.pytorch.org/tutorial/data.zip
# !unzip data.zip
# Out:
# --2019-11-25 19:55:54--  https://download.pytorch.org/tutorial/data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 13.224.29.19, 13.224.29.48, 13.224.29.73, ...
# Connecting to download.pytorch.org (download.pytorch.org)|13.224.29.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2882130 (2.7M) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>]   2.75M  6.13MB/s    in 0.4s
#
# 2019-11-25 19:55:55 (6.13 MB/s) - ‘data.zip’ saved [2882130/2882130]
#
# Archive:  data.zip
#    creating: data/
#   inflating: data/eng-fra.txt
#    creating: data/names/
#   inflating: data/names/Arabic.txt
#   inflating: data/names/Chinese.txt
#   inflating: data/names/Czech.txt
#   inflating: data/names/Dutch.txt
#   inflating: data/names/English.txt
#   inflating: data/names/French.txt
#   inflating: data/names/German.txt
#   inflating: data/names/Greek.txt
#   inflating: data/names/Irish.txt
#   inflating: data/names/Italian.txt
#   inflating: data/names/Japanese.txt
#   inflating: data/names/Korean.txt
#   inflating: data/names/Polish.txt
#   inflating: data/names/Portuguese.txt
#   inflating: data/names/Russian.txt
#   inflating: data/names/Scottish.txt
#   inflating: data/names/Spanish.txt
#   inflating: data/names/Vietnamese.txt

# %%
import os
from collections import defaultdict
def load_names(directory):
    dataset = defaultdict(list)
    languages = {}
    for language_num, file_name in enumerate(os.listdir(directory)):
        languages[language_num] = file_name
        file_name = os.path.join(directory, file_name)
        with open(file_name, "r") as r:
            for line in r:
                dataset[language_num].append(line.strip())
    return dataset, languages

dataset, languages = load_names("data/names")

# %%
import random
train_names = []
val_names = []
train_labels = []
val_labels = []
for language_num, names in dataset.items():
    random.shuffle(names)
    border = int(len(names) * 0.9)
    train_names.extend(names[:border])
    val_names.extend(names[border:])
    train_labels.extend([language_num] * border)
    val_labels.extend([language_num] * (len(names) - border))

# %%
char_set = ["<pad>"] + list({ch for name in train_names + val_names for ch in name})
print(char_set)
# Out:
# ['<pad>', 'l', 'c', 'J', 'F', 'V', ':', 'ê', 'z', '/', 'b', 'f', 'D', 'L', 'ä', 'E', 'ą', 'ò', 'g', 'p', 'I', 'O', 'v', 'd', 'P', 'è', 'A', 'u', 'C', 'õ', 'à', 'B', 'S', 'ì', 'ó', 'Z', 'H', 'Y', 'o', 'e', 'W', 'i', 'ż', 'K', 'ö', 'm', 'ł', 'ß', 'N', '1', 'ù', 'h', ',', 'É', 'x', 'é', 'G', 'í', 'ń', 't', 'X', 'ü', 's', 'M', 'n', ' ', 'Ż', 'ú', 'q', 'y', 'Q', 'j', '\xa0', 'r', 'á', 'R', 'Á', 'ñ', 'ç', 'a', 'w', '-', 'Ś', 'U', 'ã', 'k', "'", 'T']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import time
import numpy as np

def get_next_gen_batch(names, labels, max_seq_len=100, batch_size=128):
    indices = np.arange(len(names))
    np.random.shuffle(indices)
    batch_begin = 0
    while batch_begin < len(names):
        batch_indices = indices[batch_begin: batch_begin + batch_size]
        batch = []
        batch_labels = []
        batch_max_len = 0
        for data_ind in batch_indices:
            batch_labels.append(labels[data_ind])
            sample = [char_set.index(ch) for ch in names[data_ind]][:max_seq_len]
            batch_max_len = max(batch_max_len, len(sample))
            sample += [0] * (max_seq_len - len(sample))
            batch.append(sample)
        batch_begin += batch_size
        batch = torch.cuda.LongTensor(batch)[:, :batch_max_len]
        yield batch, torch.cuda.LongTensor(batch_labels)


def train_gen_model(model, names, labels, val_names, val_labels, epochs_count=10, 
                loss_every_nsteps=1000, lr=0.01, save_path="model.pt", device_name="cuda"):
    params_count = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print("Trainable params: {}".format(params_count))
    device = torch.device(device_name)
    model = model.to(device)
    total_loss = 0
    start_time = time.time()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_function = nn.CrossEntropyLoss().cuda()
    prev_avg_val_loss = None
    for epoch in range(epochs_count):
        model.train()
        for step, (batch, batch_labels) in enumerate(get_next_gen_batch(names, labels)):
            logits = model(batch_labels, batch)[:, :-1] # Прямой проход
            logits = logits.transpose(1, 2)
            loss = loss_function(logits, batch) # Подсчёт ошибки
            loss.backward() # Подсчёт градиентов dL/dw
            optimizer.step() # Градиентный спуск или его модификации (в данном случае Adam)
            optimizer.zero_grad() # Зануление градиентов, чтобы их спокойно менять на следующей итерации
            total_loss += loss.item()
        val_total_loss = 0
        val_batch_count = 0
        model.eval()
        for _, (batch, batch_labels) in enumerate(get_next_gen_batch(val_names, val_labels)):
            logits = model(batch_labels, batch)[:, :-1] # Прямой проход
            logits = logits.transpose(1, 2)
            val_total_loss += loss_function(logits, batch) # Подсчёт ошибки
            val_batch_count += 1
        avg_val_loss = val_total_loss/val_batch_count
        print("Epoch = {}, Avg Train Loss = {:.4f}, Avg val loss = {:.4f}, Time = {:.2f}s".format(epoch, total_loss / loss_every_nsteps, avg_val_loss, time.time() - start_time))
        total_loss = 0
        start_time = time.time()

        if prev_avg_val_loss is not None and avg_val_loss > prev_avg_val_loss:
            model.load_state_dict(torch.load(save_path))
            model.eval()
            break
        prev_avg_val_loss = avg_val_loss
        torch.save(model.state_dict(), save_path)

# %%
import torch
from torch import nn

class RnnGenModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=32):
        super().__init__()
        
        self.embeddings_layer = nn.Embedding(vocab_size, embedding_dim)
        self.lstm_layer = nn.LSTM(embedding_dim+1, embedding_dim, batch_first=True)
        self.out_layer = nn.Linear(embedding_dim, vocab_size)

    def forward(self, labels, inputs):
        padding = torch.zeros((inputs.size(0), ), device="cuda", dtype=torch.int64)
        padding = padding.unsqueeze(1)
        inputs = torch.cat((padding, inputs), 1)
        projections = self.embeddings_layer.forward(inputs)
        labels = labels.repeat(projections.size(1), 1).transpose(0, 1).unsqueeze(2).float()
        projections = torch.cat((projections, labels), 2)
        output, _= self.lstm_layer(projections)
        output = self.out_layer.forward(output)
        return output

model = RnnGenModel(len(char_set))
train_gen_model(model, train_names, train_labels, val_names, val_labels)
# Out:
# Trainable params: 14296
# Epoch = 0, Avg Train Loss = 0.2453, Avg val loss = 1.3857, Time = 0.78s
# Epoch = 1, Avg Train Loss = 0.1976, Avg val loss = 1.3031, Time = 0.63s
# Epoch = 2, Avg Train Loss = 0.1889, Avg val loss = 1.2516, Time = 0.67s
# Epoch = 3, Avg Train Loss = 0.1841, Avg val loss = 1.2468, Time = 0.65s
# Epoch = 4, Avg Train Loss = 0.1813, Avg val loss = 1.2423, Time = 0.65s
# Epoch = 5, Avg Train Loss = 0.1799, Avg val loss = 1.2157, Time = 0.63s
# Epoch = 6, Avg Train Loss = 0.1763, Avg val loss = 1.2112, Time = 0.63s
# Epoch = 7, Avg Train Loss = 0.1749, Avg val loss = 1.2226, Time = 0.63s

# %%
print(languages)
# Out:
# {0: 'Arabic.txt', 1: 'English.txt', 2: 'Vietnamese.txt', 3: 'Chinese.txt', 4: 'Polish.txt', 5: 'Irish.txt', 6: 'Russian.txt', 7: 'Czech.txt', 8: 'Korean.txt', 9: 'Portuguese.txt', 10: 'Scottish.txt', 11: 'German.txt', 12: 'Japanese.txt', 13: 'Spanish.txt', 14: 'Dutch.txt', 15: 'Greek.txt', 16: 'Italian.txt', 17: 'French.txt'}

# %%
seed = torch.zeros((1, 1), dtype=torch.int64, device="cuda")
first_letter = 'B'
seed[0][0] = char_set.index(first_letter)

lang = torch.zeros((1, ), dtype=torch.int64, device="cuda")
lang[0] = 6

name = ""
next_char = first_letter
while next_char != "<pad>":
    name += next_char
    logits = model(lang, seed)
    index = torch.max(logits[0][len(name)], dim=0)[1]
    index = index.unsqueeze(0).unsqueeze(0)
    seed = torch.cat((seed, index), 1)
    next_char = char_set[index]

print(name)
# Out:
# Bakhanov
